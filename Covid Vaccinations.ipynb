# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sbn

# %%
file_path = r"C:\Users\Rahi\OneDrive\Desktop\covid_vaccination\us_state_vaccinations.csv"
df = pd.read_csv(file_path)# Load the CSV file here

# %%
df
# Out:
#              date location  total_vaccinations  total_distributed  \
# 0      2021-01-12  Alabama             78134.0           377025.0
# 1      2021-01-13  Alabama             84040.0           378975.0
# 2      2021-01-14  Alabama             92300.0           435350.0
# 3      2021-01-15  Alabama            100567.0           444650.0
# 4      2021-01-16  Alabama                 NaN                NaN
# ...           ...      ...                 ...                ...
# 54623  2023-05-06  Wyoming                 NaN                NaN
# 54624  2023-05-07  Wyoming                 NaN                NaN
# 54625  2023-05-08  Wyoming                 NaN                NaN
# 54626  2023-05-09  Wyoming                 NaN                NaN
# 54627  2023-05-10  Wyoming            854132.0          1281755.0
#
#        people_vaccinated  people_fully_vaccinated_per_hundred  \
# 0                70861.0                                 0.15
# ...

# %%
df.info()  #This function gives us the number of entries, columns, and data types as well
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54628 entries, 0 to 54627
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   date                                 54628 non-null  object
#  1   location                             54628 non-null  object
#  2   total_vaccinations                   32532 non-null  float64
#  3   total_distributed                    32272 non-null  float64
#  4   people_vaccinated                    32268 non-null  float64
#  5   people_fully_vaccinated_per_hundred  30651 non-null  float64
#  6   total_vaccinations_per_hundred       30750 non-null  float64
#  7   people_fully_vaccinated              32188 non-null  float64
#  8   people_vaccinated_per_hundred        30726 non-null  float64
#  9   distributed_per_hundred              30730 non-null  float64
#  10  daily_vaccinations_raw               28354 non-null  float64
# ...

# %%
df.head() #returns the first 5 rows
# Out:
#          date location  total_vaccinations  total_distributed  \
# 0  2021-01-12  Alabama             78134.0           377025.0
# 1  2021-01-13  Alabama             84040.0           378975.0
# 2  2021-01-14  Alabama             92300.0           435350.0
# 3  2021-01-15  Alabama            100567.0           444650.0
# 4  2021-01-16  Alabama                 NaN                NaN
#
#    people_vaccinated  people_fully_vaccinated_per_hundred  \
# 0            70861.0                                 0.15
# 1            74792.0                                 0.19
# 2            80480.0                                  NaN
# 3            86956.0                                 0.28
# 4                NaN                                  NaN
#
#    total_vaccinations_per_hundred  people_fully_vaccinated  \
# 0                            1.59                   7270.0
# 1                            1.71                   9245.0
# ...

# %%
missing_values = df.isnull().sum() #Check for missing values in each column
print(missing_values)
# Out:
# date                                       0
# location                                   0
# total_vaccinations                     22096
# total_distributed                      22356
# people_vaccinated                      22360
# people_fully_vaccinated_per_hundred    23977
# total_vaccinations_per_hundred         23878
# people_fully_vaccinated                22440
# people_vaccinated_per_hundred          23902
# distributed_per_hundred                23898
# daily_vaccinations_raw                 26274
# daily_vaccinations                        65
# daily_vaccinations_per_million          2912
# share_doses_used                       22356
# total_boosters                         36512
# total_boosters_per_hundred             37374
# dtype: int64

# %%
sumstats = df.describe()  #Provides an overview of the certain stats such as mean, median, etc.
print(sumstats)
# Out:
#        total_vaccinations  total_distributed  people_vaccinated  \
# count        3.253200e+04       3.227200e+04       3.226800e+04
# mean         1.185199e+07       1.498832e+07       5.909278e+06
# std          5.198221e+07       6.626668e+07       2.508631e+07
# min          4.160000e+02       6.000000e+03       4.010000e+02
# 25%          9.277308e+05       1.188560e+06       5.043098e+05
# 50%          3.199256e+06       4.051065e+06       1.730820e+06
# 75%          7.948546e+06       1.006490e+07       4.023565e+06
# max          6.767288e+08       9.844443e+08       2.702272e+08
#
#        people_fully_vaccinated_per_hundred  total_vaccinations_per_hundred  \
# count                         30651.000000                    30750.000000
# mean                             47.332224                      114.716897
# std                              22.037456                       57.873521
# min                               0.000000                        0.170000
# ...

# %%
plt.figure(figsize=(12, 8)) #this will give us the distribution of the columns
df['total_vaccinations'].dropna().plot(kind='hist', bins=50, color='royalblue')
plt.title('The Distribution of Total Vaccinations')
plt.xlabel('Total # of Vaccinations')
plt.ylabel('Frequency of Vaccinations')
plt.show()

# %%
df['date'] = pd.to_datetime(df['date']) #another way to show the trend of daily vaccinations every day 
daily_vacc_trend = df.groupby('date')['daily_vaccinations'].sum()

# %%
plt.figure(figsize=(12, 8))
daily_vacc_trend.plot()
plt.title('Daily Vaccinations Over a Certain Period')
plt.xlabel('Date By Month')
plt.ylabel('Number of Vaccinations')
plt.grid(True)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54628 entries, 0 to 54627
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   date                                 54628 non-null  datetime64[ns]
#  1   location                             54628 non-null  object
#  2   total_vaccinations                   32532 non-null  float64
#  3   total_distributed                    32272 non-null  float64
#  4   people_vaccinated                    32268 non-null  float64
#  5   people_fully_vaccinated_per_hundred  30651 non-null  float64
#  6   total_vaccinations_per_hundred       30750 non-null  float64
#  7   people_fully_vaccinated              32188 non-null  float64
#  8   people_vaccinated_per_hundred        30726 non-null  float64
#  9   distributed_per_hundred              30730 non-null  float64
# ...

# %%
df.transpose()
# Out:
#                                                    0                    1      \
# date                                 2021-01-12 00:00:00  2021-01-13 00:00:00
# location                                         Alabama              Alabama
# total_vaccinations                               78134.0              84040.0
# total_distributed                               377025.0             378975.0
# people_vaccinated                                70861.0              74792.0
# people_fully_vaccinated_per_hundred                 0.15                 0.19
# total_vaccinations_per_hundred                      1.59                 1.71
# people_fully_vaccinated                           7270.0               9245.0
# people_vaccinated_per_hundred                       1.45                 1.53
# distributed_per_hundred                             7.69                 7.73
# daily_vaccinations_raw                               NaN               5906.0
# ...
